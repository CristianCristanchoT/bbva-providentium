# %%
import pandas as pd

# %%
df1 = pd.read_csv('ECrecer_Clientes_Col.csv')
df2 = pd.read_csv('ECrecer_Clientes_Mex.csv')
df3 = pd.read_csv('ECrecer_Clientes_Esp.csv')

Lista = [df1, df2, df3]

df_Crecer = pd.concat(Lista)
df_Crecer.head()
print(df_Crecer.shape)
df_Crecer.to_csv('Df_Crecer_Clientes_Consolidado.csv', index=False)
# Out:
# (2104, 9)

# %%
df_Crecer
# Out:
#                       Id              NombreUsuario         Usuario  \
# 0    1448800506823028736                          🌞           _06lm
# 1    1448800401067806722                          🌸      brookerprr
# 2    1448799912808882181                Bancolombia     Bancolombia
# 3    1448799364227510273                     Marsky     Marskyblue7
# 4    1448799156768841731                Bancolombia     Bancolombia
# ..                   ...                        ...             ...
# 100  1448680446292865024       RegnumChristi España       RC_Espana
# 101  1448607470293852165                 Mamisaoshi       Misaoshi_
# 102  1448587708495015940               FXMAG España    FXMAG_Espana
# 103  1448583599788281858         observatoriorh.com          ORH_RH
# 104  1448537684721405952  Santander España Responde  santander_resp
#
#               FechaPublicacion  \
# 0    2021-10-14 23:58:52+00:00
# 1    2021-10-14 23:58:27+00:00
# 2    2021-10-14 23:56:31+00:00
# ...

# %%
df11 = pd.read_csv('Excel_Operativa_Col.csv')
df22 = pd.read_csv('Excel_Operativa_Mex.csv')
df33 = pd.read_csv('Excel_Operativa_Esp.csv')

Lista = [df11, df22, df33]

df_Excel = pd.concat(Lista)
df_Excel.head()
print(df_Excel.shape)
df_Excel.to_csv('Df_Excel_Operativa_Consolidado.csv', index=False)
# Out:
# (1358, 9)

# %%
df_Excel
# Out:
#                       Id         NombreUsuario          Usuario  \
# 0    1448795143146979333      BBVA en Colombia    BBVA_Colombia
# 1    1448783577072689155       Jackie Villegas     jakivillegas
# 2    1448782067714646023      BBVA en Colombia    BBVA_Colombia
# 3    1448779812009619457      BBVA en Colombia    BBVA_Colombia
# 4    1448779352196407298        joaquin metrio    joaquinmetrio
# ..                   ...                   ...              ...
# 447  1449073018102325250  BBVABancaResponsable  BBVABancaRespon
# 448  1449068976831713282  Sergio Redondo Muñoz       sergiorm10
# 449  1449059055037820933                    JH       KelliHayek
# 450  1449052703288594439            prnoticias       prnoticias
# 451  1449026056078467075      Domestika Empleo  domestikaempleo
#
#               FechaPublicacion  \
# 0    2021-10-14 23:37:34+00:00
# 1    2021-10-14 22:51:36+00:00
# 2    2021-10-14 22:45:36+00:00
# 3    2021-10-14 22:36:38+00:00
# 4    2021-10-14 22:34:49+00:00
# ...

# %%
df111 = pd.read_csv('Futuro_Sostenible_Colombia.csv')
df222 = pd.read_csv('Futuro_Sostenible_Mexico.csv')
df333 = pd.read_csv('Futuro_Sostenible_España.csv')

Lista = [df111, df222, df333]

df_f = pd.concat(Lista)
df_f.head()
print(df_f.shape)
df_f.to_csv('Df_Futuro_Sostenible_Consolidado.csv', index=False)
# Out:
# (105, 9)

# %%
df_f
# Out:
#                      Id                        NombreUsuario          Usuario  \
# 0   1448754686631231490                  Alberto Muñoz Gomez    AlbertoMunnoz
# 1   1448656877634547716                         FAO Colombia     FAO_Colombia
# 2   1449148077579784192                         FAO Colombia     FAO_Colombia
# 3   1449107874525978627  Consejo Mundial de Energía Colombia     WEC_COLOMBIA
# 4   1449038649467756544           HERNANDO ARISTIZABAL URIBE  HERNANDOARISTI4
# ..                  ...                                  ...              ...
# 31  1449287496265699332                    Ecoembes Comunica     ecoembes_com
# 32  1449018599868403725                   Pablo García Rubio       PabloGaRub
# 33  1448736423637512195                       Diego Giuliano    DiegoGiuliano
# 34  1448629417786368002                       Diego Giuliano    DiegoGiuliano
# 35  1448615730824495106                           IDE España        IDEESpain
#
#              FechaPublicacion  \
# ...

# %%
df11 = pd.read_csv('Futuro_Sostenible_Colombia.csv')
df22 = pd.read_csv('Futuro_Sostenible_España.csv')
df33 = pd.read_csv('Futuro_Sostenible_Mexico.csv')

Lista = [df11, df22, df33]

df_1 = pd.concat(Lista)
df_1.head()
print(df_1.shape)
df_1.to_csv('Df_Futuro_Sostenible_Consolidado.csv', index=False)
# Out:
# (1593, 9)

# %%
df_1
# Out:
#                       Id                                     NombreUsuario  \
# 0    1448754686631231490                               Alberto Muñoz Gomez
# 1    1448656877634547716                                      FAO Colombia
# 2    1448800150315540482                Elio Ohep - Editor Petroleumworld1
# 3    1448780004981018624  Edición Universitaria América Latina y el Caribe
# 4    1448689989127180295                                            Zenger
# ..                   ...                                               ...
# 761  1450126575123451905                                    Eduardo Pliego
# 762  1450126058565550089                                     Corte de Caja
# 763  1450126021676654593                                   Bloomberg Línea
# 764  1450123625521041411                               Noticias En La Mira
# 765  1450121389831294982                             Gustaaf el de la bici
#
#              Usuario           FechaPublicacion  \
# ...

# %%
df_1.Pais.unique()
# Out:
# array(['Colombia', 'España', 'Mexico'], dtype=object)

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#                    Tipo      Pais Fuente  \
# 0  Excelencia Operativa  Colombia   Apps
# 1  Excelencia Operativa  Colombia   Apps
# 2  Excelencia Operativa  Colombia   Apps
# 3  Excelencia Operativa  Colombia   Apps
# 4  Excelencia Operativa  Colombia   Apps
#
#                                                Texto     FechaPublicacion  \
# 0  Muy mala la app como una hora pidiendo un Códi...  2021-10-22 16:22:53
# 1                    Un poquito lenta pero excelente  2021-10-22 16:03:49
# 2  Que aplicacion tan mala, con tanto que roban d...  2021-10-22 15:13:42
# 3  Muy lenta, se nota lo pesada... Debe ser mas i...  2021-10-22 14:56:23
# 4            Muy buena lo mejor que han podido crear  2021-10-22 14:48:38
#
#   sentimiento  sentimiento_numerico
# 0    Negativo                  0.00
# 1    Positivo                  0.94
# 2    Negativo                  0.00
# 3    Negativo                  0.00
# 4    Positivo                  0.55

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6907 entries, 0 to 6906
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Tipo                  6907 non-null   object
#  1   Pais                  6907 non-null   object
#  2   Fuente                6907 non-null   object
#  3   Texto                 6907 non-null   object
#  4   FechaPublicacion      6907 non-null   object
#  5   sentimiento           6907 non-null   object
#  6   sentimiento_numerico  6907 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 377.9+ KB

# %%
data.Tipo.value_counts()
# Out:
# Excelencia Operativa    3210
# Crecer Clientes         2104
# Futuro sostenible       1593
# Name: Tipo, dtype: int64

# %%
data[data['Tipo']=='Crecer Clientes']
# Out:
#                  Tipo      Pais   Fuente  \
# 1852  Crecer Clientes  Colombia  Twitter
# 1853  Crecer Clientes  Colombia  Twitter
# 1854  Crecer Clientes  Colombia  Twitter
# 1855  Crecer Clientes  Colombia  Twitter
# 1856  Crecer Clientes  Colombia  Twitter
# ...               ...       ...      ...
# 3951  Crecer Clientes    España  Twitter
# 3952  Crecer Clientes    España  Twitter
# 3953  Crecer Clientes    España  Twitter
# 3954  Crecer Clientes    España  Twitter
# 3955  Crecer Clientes    España  Twitter
#
#                                                   Texto  \
# 1852  Mañana es quincena y se cae bancolombia. https...
# 1853  el corazón se me sale cada vez que reviso mi c...
# 1854  @snchzkevin_ ¡Kevin, hola!\nEsperamos que este...
# 1855  @AsociacionMi Dios mío ese desgraciado q hizo ...
# 1856  @vickysyta ¡Hola! Te estamos esperando por int...
# ...                                                 ...
# 3951  🛒 La @fundaltius_es recibe el premio “Euros en...
# ...
